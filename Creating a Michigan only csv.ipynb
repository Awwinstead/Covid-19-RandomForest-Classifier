# %%
import pandas as pd
df = pd.read_csv("US_MI_deaths.csv") 
df.fillna(0, inplace=True)

# %%
state = ["Michigan"]
ddf = df[df.Province_State.isin(state)]
ddf
# Out:
#              UID iso2 iso3  code3     FIPS  \
# 1236  84026001.0   US  USA    840  26001.0
# 1237  84026003.0   US  USA    840  26003.0
# 1238  84026005.0   US  USA    840  26005.0
# 1239  84026007.0   US  USA    840  26007.0
# 1240  84026009.0   US  USA    840  26009.0
# ...          ...  ...  ...    ...      ...
# 1318  84026165.0   US  USA    840  26165.0
# 3171  84080026.0   US  USA    840  80026.0
# 3223  84090026.0   US  USA    840  90026.0
# 3253  84070004.0   US  USA    840      0.0
# 3254  84070005.0   US  USA    840      0.0
#
#                                          Admin2 Province_State Country_Region  \
# 1236                                     Alcona       Michigan             US
# 1237                                      Alger       Michigan             US
# 1238                                    Allegan       Michigan             US
# 1239                                     Alpena       Michigan             US
# ...

# %%
df = ddf.drop(ddf.columns[[0,1,3,4,7,8,9]], axis=1)
df
# Out:
#      iso3                                     Admin2 Province_State  \
# 1236  USA                                     Alcona       Michigan
# 1237  USA                                      Alger       Michigan
# 1238  USA                                    Allegan       Michigan
# 1239  USA                                     Alpena       Michigan
# 1240  USA                                     Antrim       Michigan
# ...   ...                                        ...            ...
# 1318  USA                                    Wexford       Michigan
# 3171  USA                                  Out of MI       Michigan
# 3223  USA                                 Unassigned       Michigan
# 3253  USA  Michigan Department of Corrections (MDOC)       Michigan
# 3254  USA     Federal Correctional Institution (FCI)       Michigan
#
#                                            Combined_Key  Population  1/22/20  \
# ...

# %%
SUM = df.sum(axis=0)
print(SUM.to_string())
# Out:
# Population    9986857
# 1/22/20             0
# 1/23/20             0
# 1/24/20             0
# 1/25/20             0
# 1/26/20             0
# 1/27/20             0
# 1/28/20             0
# 1/29/20             0
# 1/30/20             0
# 1/31/20             0
# 2/1/20              0
# 2/2/20              0
# 2/3/20              0
# 2/4/20              0
# 2/5/20              0
# 2/6/20              0
# 2/7/20              0
# 2/8/20              0
# 2/9/20              0
# 2/10/20             0
# 2/11/20             0
# 2/12/20             0
# 2/13/20             0
# 2/14/20             0
# 2/15/20             0
# 2/16/20             0
# 2/17/20             0
# 2/18/20             0
# 2/19/20             0
# 2/20/20             0
# 2/21/20             0
# 2/22/20             0
# 2/23/20             0
# 2/24/20             0
# 2/25/20             0
# 2/26/20             0
# 2/27/20             0
# 2/28/20             0
# 2/29/20             0
# 3/1/20              0
# ...

# %%
SUM.to_csv(r'\Users\awwin/Jupyter files/A.... Stats Project/MI_Deaths(4-27).csv', index = False)
# Out:
# C:\Users\awwin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
