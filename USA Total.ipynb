# %%
import pandas as pd
df = pd.read_csv("Recovered_Global.csv") #replace csv for differnet file.
df.fillna(0, inplace=True)
df
# Out:
#                 Province_State         Country_Region        Lat       Long  \
# 0                            0            Afghanistan  33.000000  65.000000
# 1                            0                Albania  41.153300  20.168300
# 2                            0                Algeria  28.033900   1.659600
# 3                            0                Andorra  42.506300   1.521800
# 4                            0                 Angola -11.202700  17.873900
# ..                         ...                    ...        ...        ...
# 245  Saint Pierre and Miquelon                 France  46.885200 -56.315900
# 246                          0            South Sudan   6.877000  31.307000
# 247                          0         Western Sahara  24.215500 -12.885800
# 248                          0  Sao Tome and Principe   0.186360   6.613081
# 249                          0                  Yemen  15.552727  48.516388
#
# ...

# %%
country = ["US"]
ddf = df[df.Country_Region.isin(country)]
ddf
# Out:
#     Province_State Country_Region      Lat     Long  1/22/20  1/23/20  \
# 225              0             US  37.0902 -95.7129        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  4/18/20  4/19/20  4/20/20  \
# 225        0        0        0        0  ...    64840    70337    72329
#
#      4/21/20  4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20
# 225    75204    77366    80203    99079   100372   106988   111424
#
# [1 rows x 101 columns]

# %%
ddf = ddf.drop(ddf.columns[[0,2,3]], axis=1)
ddf
# Out:
#     Country_Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 225             US        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  4/18/20  4/19/20  4/20/20  4/21/20  \
# 225        0        0        0  ...    64840    70337    72329    75204
#
#      4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20
# 225    77366    80203    99079   100372   106988   111424
#
# [1 rows x 98 columns]

# %%
SUM = ddf.sum(axis=0)
print(SUM.to_string())
# Out:
# Country_Region        US
# 1/22/20                0
# 1/23/20                0
# 1/24/20                0
# 1/25/20                0
# 1/26/20                0
# 1/27/20                0
# 1/28/20                0
# 1/29/20                0
# 1/30/20                0
# 1/31/20                0
# 2/1/20                 0
# 2/2/20                 0
# 2/3/20                 0
# 2/4/20                 0
# 2/5/20                 0
# 2/6/20                 0
# 2/7/20                 0
# 2/8/20                 0
# 2/9/20                 3
# 2/10/20                3
# 2/11/20                3
# 2/12/20                3
# 2/13/20                3
# 2/14/20                3
# 2/15/20                3
# 2/16/20                3
# 2/17/20                3
# 2/18/20                3
# 2/19/20                3
# 2/20/20                3
# 2/21/20                5
# 2/22/20                5
# 2/23/20                5
# 2/24/20                5
# 2/25/20                6
# 2/26/20                6
# ...

# %%
SUM
# Out:
# Country_Region        US
# 1/22/20                0
# 1/23/20                0
# 1/24/20                0
# 1/25/20                0
#                    ...
# 4/23/20            80203
# 4/24/20            99079
# 4/25/20           100372
# 4/26/20           106988
# 4/27/20           111424
# Length: 98, dtype: object

# %%
#make sure to save with a new name.
SUM.to_csv(r'\Users\awwin/Jupyter files/A.... Stats Project/Recoveries_USA_Total.csv', index = False)
# Out:
# C:\Users\awwin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
